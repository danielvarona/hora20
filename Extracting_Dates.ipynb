# %% [markdown]
# ## Extraer Fechas

# %%
import os
import json
from bs4 import BeautifulSoup
import glob
import re

# %%
DIR_DATA = 'Data/'

# %%
os.listdir(DIR_DATA)[:20]
# Out:
# ['caracol_radio_hora20_20160413_200000_210000.rtf',
#  'caracol_radio_hora20_20161122_200000_210000.rtf',
#  'caracol_radio_hora20_20160831_200000_210000.rtf',
#  '097RD010000000401090_20160921.rtf',
#  '097RD130000000436597.rtf',
#  'caracol_radio_hora20_20160106_190000_200000.rtf',
#  'caracol_radio_hora20_20160719_190000_200000.rtf',
#  'caracol_radio_hora20_20160428_200000_210000.rtf',
#  'caracol_radio_hora20_20160927_190000_200000.rtf',
#  '097RD010000000433767.rtf',
#  '097RD010000000445556.rtf',
#  'caracol_radio_hora20_20160603_190000_193000.rtf',
#  'caracol_radio_hora20_20160524_190000_200000.rtf',
#  '097RD130000000405954_20160929.rtf',
#  '097RD010000000368334_20160725.rtf',
#  '097RD010000000382607_20160819.rtf',
#  'caracol_radio_hora20_20160411_190000_200000.rtf',
#  '097RD130000000418279.rtf',
#  'caracol_radio_hora20_20160530_190000_200000.rtf',
#  'caracol_radio_hora20_20160219_200000_210000.rtf']

# %%
data = {}
with open('topics_hora20.json') as data_file:    
    data = json.load(data_file)

# %%
for key in data.keys()
    if ' _.html' in key:
        key.replace(' _.html', '')
        data

# %%
def extract_dates(text):
    dates = []
    patron = re.compile('((primero|uno|dos|tres|cuatro|cinco|seis|siete|ocho|nueve|diez|once|doce|trece|catorce|quince|dieciséis|diecisiete|dieciocho|diecinueve|veinte|veintiuno|vientidos|veintitres|veinticuatro|veinticinco|veintiséis|veintisiete|veintiocho|veintinueve|treinta|treinta y uno) de (enero|febrero|marzo|abril|mayo|junio|julio|agosto|septiembre|octubre|noviembre|diciembre) de ((mil|dos mil) (cien|doscientos|trescientos|cuatrocientos|quinientos|seiscientos|setecientos|ochocientos|novecientos)( dieci| veinti| treinta y| cuarenta y| cincuenta y| sesenta y| setenta y| ochenta y| noventa y)?( )?(uno|dos|tres|cuatro|cinco|seis|séis|siete|ocho|nueve|diez|once|doce|trece|catorce|quince)))')
    dates = patron.findall(text)    
    dates = [x[0] for x in dates]
    
    patron3 = re.compile('((del|desde el) (primero|uno|dos|tres|cuatro|cinco|seis|siete|ocho|nueve|diez|once|doce|trece|catorce|quince|dieciséis|diecisiete|dieciocho|diecinueve|veinte|veintiuno|vientidos|veintitres|veinticuatro|veinticinco|veintiséis|veintisiete|veintiocho|veintinueve|treinta|treinta y uno)( al )(primero|uno|dos|tres|cuatro|cinco|seis|siete|ocho|nueve|diez|once|doce|trece|catorce|quince|dieciséis|diecisiete|dieciocho|diecinueve|veinte|veintiuno|vientidos|veintitres|veinticuatro|veinticinco|veintiséis|veintisiete|veintiocho|veintinueve|treinta|treinta y uno)( de )?(enero|febrero|marzo|abril|mayo|junio|julio|agosto|septiembre|octubre|noviembre|diciembre)?( de )?((mil|dos mil) (cien|doscientos|trescientos|cuatrocientos|quinientos|seiscientos|setecientos|ochocientos|novecientos)( dieci| veinti| treinta y| cuarenta y| cincuenta y| sesenta y| setenta y| ochenta y| noventa y)?( )?(uno|dos|tres|cuatro|cinco|seis|séis|siete|ocho|nueve|diez|once|doce|trece|catorce|quince))?)')
    dates3 = patron3.findall(text)    
    dates3 = [x[0] for x in dates3]
    dates = dates + dates3
    
    """patron2 = re.compile('((este )?(lunes)|(martes)|(miercoles)|(miércoles)|(jueves)|(viernes)|(sabado)|(sábado)|(domingo))')
    dates2 = patron2.findall(text)    
    dates2 = [x[0] for x in dates2]
    dates = dates + dates2
   """
    patron4 = re.compile('((enero|febrero|marzo|abril|mayo|junio|julio|agosto|septiembre|octubre|noviembre|diciembre) (a|hasta) (enero|febrero|marzo|abril|mayo|junio|julio|agosto|septiembre|octubre|noviembre|diciembre)( )?(de|del)?( )?((mil|dos mil) (cien|doscientos|trescientos|cuatrocientos|quinientos|seiscientos|setecientos|ochocientos|novecientos)( dieci| veinti| treinta y| cuarenta y| cincuenta y| sesenta y| setenta y| ochenta y| noventa y)?( )?(uno|dos|tres|cuatro|cinco|seis|séis|siete|ocho|nueve|diez|once|doce|trece|catorce|quince))?)')
    dates4 = patron4.findall(text)    
    dates4 = [x[0] for x in dates4]
    dates = dates + dates4
    
    #anno a anno
    patron5 = re.compile('((mil|dos mil) (cien|doscientos|trescientos|cuatrocientos|quinientos|seiscientos|setecientos|ochocientos|novecientos)( dieci| veinti| treinta y| cuarenta y| cincuenta y| sesenta y| setenta y| ochenta y| noventa y)?( )?(uno|dos|tres|cuatro|cinco|seis|séis|siete|ocho|nueve|diez|once|doce|trece|catorce|quince) (a|al) ((dos mil|mil)()?(cien|doscientos|trescientos|cuatrocientos|quinientos|seiscientos|setecientos|ochocientos|novecientos)?( dieci| veinti| treinta y| cuarenta y| cincuenta y| sesenta y| setenta y| ochenta y| noventa y)?( )?(uno|dos|tres|cuatro|cinco|seis|séis|siete|ocho|nueve|diez|once|doce|trece|catorce|quince)))')
    dates5 = patron5.findall(text)    
    dates5 = [x[0] for x in dates5]
    dates = dates + dates5
    
    #mes del dia al dia
    patron6 = re.compile('((enero|febrero|marzo|abril|mayo|junio|julio|agosto|septiembre|octubre|noviembre|diciembre)  (de|del|desde el)( )?(día)?( )?(primero|uno|dos|tres|cuatro|cinco|seis|siete|ocho|nueve|diez|once|doce|trece|catorce|quince|dieciséis|diecisiete|dieciocho|diecinueve|veinte|veintiuno|vientidos|veintitres|veinticuatro|veinticinco|veintiséis|veintisiete|veintiocho|veintinueve|treinta|treinta y uno) (a|hasta|hasta el) (día)?( )?(primero|uno|dos|tres|cuatro|cinco|seis|siete|ocho|nueve|diez|once|doce|trece|catorce|quince|dieciséis|diecisiete|dieciocho|diecinueve|veinte|veintiuno|vientidos|veintitres|veinticuatro|veinticinco|veintiséis|veintisiete|veintiocho|veintinueve|treinta|treinta y uno))')
    dates6 = patron6.findall(text)    
    dates6 = [x[0] for x in dates6]
    dates = dates + dates6
    
    return dates

extract_dates("prueba en enero del cinco al diecinueve")
# Out:
# ['del cinco al diecinueve']

# %%
import datetime
for filename in glob.glob(os.path.join(DIR_DATA, '*.rtf')):
    with open(filename) as f:
        key = filename[:-4].replace(DIR_DATA, '')        
        if key in data.keys():            
            text = f.read()
            dates = extract_dates(text.lower())
            if('hoy' in text and data[key]['date'] is not None):                
                dates.append('hoy')
            if('ayer' in text and data[key]['date'] is not None):
                dates.append('ayer')
            if('mañana' in text and data[key]['date'] is not None):
                dates.append('mañana')
            if len(dates) > 0:
                print (dates)
            data[key]['dates'] = dates
# Out:
# ['hoy', 'ayer']
# ['hoy', 'ayer']
# ['hoy', 'ayer']
# ['hoy', 'ayer']
# ['hoy']
# ['del dos al tres de febrero', 'hoy', 'ayer']
# ['hoy', 'ayer']
# ['hoy']
# ['hoy']
# ['hoy']
# ['hoy', 'ayer']
# ['hoy', 'ayer']
# ['abril a abril ', 'hoy']
# ['hoy', 'ayer']
# ['hoy', 'ayer']
# ['del tres al cuatro de ', 'hoy']
# ['del primero al siete de febrero', 'hoy']
# ['hoy']
# ['hoy']
# ['hoy']
# ['hoy', 'ayer']
# ['hoy', 'ayer']
# ['del tres al seis']
# ['hoy']
# ['hoy']
# ['hoy']
# ['hoy', 'ayer']
# ['hoy']
# ['hoy']
# ['hoy', 'ayer']
# ['hoy']
# ['del cinco al doce de noviembre', 'hoy']
# ['hoy', 'ayer']
# ['hoy']
# ['del once al catorce de agosto', 'hoy', 'ayer']
# ['hoy']
# ['ayer']
# ['hoy']
# ['del dos al veintiuno de agosto', 'hoy', 'ayer']
# ['hoy']
# ['hoy', 'ayer']
# ['hoy']
# ['hoy']
# ['del primero al siete de febrero', 'hoy']
# ['hoy', 'ayer']
# ['del primero al treinta', 'hoy', 'ayer']
# ['hoy', 'ayer']
# ['hoy']
# ['del seis al siete de junio', 'hoy']
# ['hoy', 'ayer']
# ...

# %%
data.keys()
# Out:
# dict_keys(['097RD130000000396993_20160914', '097RD130000000367078_20160722', '097RD130000000405954_20160929', 'caracol_radio_hora20_20160113_190000_200000', '097RD010000000429311', 'caracol_radio_hora20_20160120_200000_210000', 'caracol_radio_hora20_20160822_190000_200000', 'caracol_radio_hora20_20160928_200000_210000', '097RD010000000372811_20160802', 'caracol_radio_hora20_20160217_190000_200000', 'caracol_radio_hora20_20160408_200000_210000', 'caracol_radio_hora20_20160510_200000_210000', 'caracol_radio_hora20_20160216_190000_200000', '097RD130000000448484', 'caracol_radio_hora20_20161117_190000_200000', '097RD130000000388490_20160830', '097RD130000000418202', 'caracol_radio_hora20_20160321_200000_210000', 'caracol_radio_hora20_20160712_190000_200000', '097RD010000000447901', '097RD010000000404446_20160927', '097RD010000000391670_20160905', '097RD010000000405187_20160928', '097RD130000000414014', 'caracol_radio_hora20_20160908_200000_210000', 'caracol_radio_hora20_20160831_200000_2
# ...
